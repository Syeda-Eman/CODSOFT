# %% [markdown]
# # **Task 3: Password Generator**

# %%
import random
import string

adjectives = ['sleepy', 'slow', 'smelly',
              'wet', 'fat', 'red',
              'bad', 'good', 'mad',
              'tall', 'tiny', 'small',
              'big', 'slim', 'pink']

nouns = ['apple', 'dinosaur', 'cat',
         'toaster', 'goat', 'dragon',
         'hammer', 'duck', 'panda']

print('Welcome to Password Picker!')

while True:
    for num in range(1):
        adjective = random.choice(adjectives)
        noun = random.choice(nouns)
        number = random.randrange(0, 100)
        special_char = random.choice(string.punctuation)

        password = adjective + noun + str(number) + special_char
        print('Your new password is: %s' % password)

    response = input('Would you like another password? Type y to continue or anything else to quit: ')

    if response.lower() != 'y':
        print('Thank you for using this app!')
        break
# Out:
# Welcome to Password Picker!
# Your new password is: fatdinosaur7#
# Would you like another password? Type y to continue or anything else to quit: y
# Your new password is: smalltoaster12(
# Would you like another password? Type y to continue or anything else to quit: o
# Thank you for using this app!
